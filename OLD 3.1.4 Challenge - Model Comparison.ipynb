# %%
'''
PROMPT:
Find a data set and build a KNN Regression and an OLS regression. 
Compare the two. 
How similar are they? 
Do they miss in different ways?
'''


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
from sklearn import neighbors
# %matplotlib inline

num = pd.read_csv('C:\\Users\\maken\\num.txt', sep = '\t')
tag = pd.read_csv('C:\\Users\\maken\\tag.txt', sep = '\t')
sub = pd.read_csv('C:\\Users\\maken\\sub.txt', sep = '\t')

# %%
num.head()
# Out:
#                    adsh                                    tag       version  \
# 0  0001477932-16-014447     EntityCommonStockSharesOutstanding      dei/2014
# 1  0001477932-16-014447  AccountsAndOtherReceivablesNetCurrent  us-gaap/2016
# 2  0001477932-16-014447  AccountsAndOtherReceivablesNetCurrent  us-gaap/2016
# 3  0001477932-16-014447           AccountsReceivableNetCurrent  us-gaap/2016
# 4  0001477932-16-014447           AccountsReceivableNetCurrent  us-gaap/2016
#
#   coreg     ddate  qtrs     uom       value  footnote
# 0   NaN  20161231     0  shares  67538142.0       NaN
# 1   NaN  20151231     0     USD         NaN       NaN
# 2   NaN  20160930     0     USD         NaN       NaN
# 3   NaN  20151231     0     USD     95563.0       NaN
# 4   NaN  20160930     0     USD    146102.0       NaN

# %%
tag.head()
# Out:
#                                                  tag       version  custom  \
# 0                             AccountsPayableCurrent  us-gaap/2015       0
# 1               AccountsPayableRelatedPartiesCurrent  us-gaap/2015       0
# 2                       AccountsReceivableNetCurrent  us-gaap/2015       0
# 3                          AccruedLiabilitiesCurrent  us-gaap/2015       0
# 4  AccumulatedDepreciationDepletionAndAmortizatio...  us-gaap/2015       0
#
#    abstract  datatype iord crdr  \
# 0         0  monetary    I    C
# 1         0  monetary    I    C
# 2         0  monetary    I    D
# 3         0  monetary    I    C
# 4         0  monetary    I    C
#
#                                               tlabel  \
# 0                          Accounts Payable, Current
# 1         Accounts Payable, Related Parties, Current
# 2                  Accounts Receivable, Net, Current
# 3                       Accrued Liabilities, Current
# ...

# %%
sub.head()
# Out:
#                    adsh   cik                               name     sic  \
# 0  0000002178-17-000019  2178     ADAMS RESOURCES & ENERGY, INC.  5172.0
# 1  0000002488-17-000043  2488         ADVANCED MICRO DEVICES INC  3674.0
# 2  0000002969-17-000010  2969  AIR PRODUCTS & CHEMICALS INC /DE/  2810.0
# 3  0000003499-17-000004  3499                     ALEXANDERS INC  6798.0
# 4  0000003545-17-000021  3545                          ALICO INC   100.0
#
#   countryba stprba      cityba       zipba  \
# 0        US     TX     HOUSTON       77027
# 1        US     CA   SUNNYVALE       94085
# 2        US     PA   ALLENTOWN  18195-1501
# 3        US     NJ     PARAMUS       07652
# 4        US     FL  FT. MYERS,       33913
#
#                                       bas1   bas2  ...      period      fy  \
# 0                   17 S. BRIAR HOLLOW LN.    NaN  ...    20161231  2016.0
# 1                               ONE AMD PL  MS 68  ...    20161231  2016.0
# ...

# %%
# Find the length of the file
len(num)
# Out:
# 1927179

# %%
# Find the length of the NaN values
sum(num['value'].isnull())
# Out:
# 39906

# %%
# Calculate the percentage of NaN values
print(39906/1927179)
# Out:
# 0.02070695041820194

# %% [markdown]
# Looks like 39906 of the 192179 values, or 2%, are NaN

# %%
# Build our model.
knn = neighbors.KNeighborsRegressor(n_neighbors=10)
X = pd.DataFrame(music.loudness)
Y = music.bpm
knn.fit(X, Y)

# Set up our prediction line.
T = np.arange(0, 50, 0.1)[:, np.newaxis]

# Trailing underscores are a common convention for a prediction.
Y_ = knn.predict(T)

plt.scatter(X, Y, c='k', label='data')
plt.plot(T, Y_, c='g', label='prediction')
plt.legend()
plt.title('K=10, Unweighted')
plt.show()

# %%
# Since we have two UoMs, make
