# %%
# Given an array of numbers, how would you write a program to determine at what point to buy (min) and sell (max)
# Where the max must occur after the min

for value in data
int value = data{0}
if value(i) < value(i-1):
        value(i) = min
    if value(i) > value(i-1):
        value(i) = max
    difference = max - min
    maxdifference = difference(i)
    if difference(i) > maxdifference(i-1)
        maxdifference = difference(i)

return value(the two values that provide maxdifference) 



4, 3, 16, 11, 1, 15, 8


1
min = data{i}
max = data{i}
difference = min - max

updatemin(i)
    min = data{i}
    
updatemax(i)
    max = data{i}

calculate_difference(max, min)
    difference = max - min
    
2
if data{i+1} > data{i}
max = data{i+1}
    updatemax(max)

3
if data{i+1} < data{i}
min = data{i+1}
    updatemin(min)

4
if new min occurs after max
    if new difference is > difference
    update difference
    
Alex's Answer

import numpy as np

prices = np.random.randint(0,50,10)
#prices = [42,37,48,27,25,31,17,34,19,45]
#prices = [44,17,32,46,7,0,17,23,38,28]

max = prices[0] #maximum set to the first element of the list
min = prices[0] #minimum set to the first element of the list
temp_min = prices[0] #temporarily minimum set to the first element of the list
difference = 0
temp_loop = 0 #marker

for price in prices:

#First case: the next element is less than temporarily and global minimums
#This step has to be the first one, it doesn't work otherwise. Can play around to see what happens
	if price < temp_min:
		#print ("loop1\t{}\t{}".format(min,max))
		temp_min = price
		temp_difference = 0
		temp_loop = 1

#Second case: we found temporarily minimum, but haven't updated the difference and maximum yet
	elif temp_loop == 1:
		#print ("loop2\t{}\t{}".format(min,max))
		temp_difference = price - temp_min
		if temp_difference > difference:
			#print ("loop2a\t{}\t{}".format(min,max))
			max = price
			min = temp_min
			difference = temp_difference
			temp_loop = 0		

#Third case: the easiest one, found the new maximum and updated the maximum and the difference
	elif price > max:
		#print ("loop3\t{}\t{}".format(min,max))
		max = price
		difference = max - min

		
		
print (prices)
print (min, max, difference)
